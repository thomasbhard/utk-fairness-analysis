# %%
from utils import *

SAVEPLOTS = False
DATASET_PATH = r"dataset\UTKFace"

df = parse_dataset(DATASET_PATH)

# %%
display(Markdown("## UTKFace Dataset Overview"))

display(Markdown(f"Number of images: {len(df)}"))
display(Markdown("Annotations:<br>- Gender: male/female<br>- Race: white/black/asian/indian/others<br>- Age: 0 - 116"))

display(Markdown("### Sample images from the UTK Dataset inlcuding labels:"))
plot_select_images(df)
# Out:
# ## UTKFace Dataset Overview
# Number of images: 23705
# Annotations:<br>- Gender: male/female<br>- Race: white/black/asian/indian/others<br>- Age: 0 - 116
# ### Sample images from the UTK Dataset inlcuding labels:

# %%
display(Markdown("## Gender, race, and age distributions for the whole UTKFace dataset"))
plot_distributions(df)
# Out:
# ## Gender, race, and age distributions for the whole UTKFace dataset

# %%
display(Markdown("## Gender distribution grouped by race"))
plot_gender_distribution_by_race(df)
# Out:
# ## Gender distribution grouped by race

# %%
display(Markdown("## Gender distribution grouped by age"))
plot_gender_distribution_by_age(df)
# Out:
# ## Gender distribution grouped by age

# %%
display(Markdown("## Age distribution grouped by gender"))
plot_age_distribution_by_gender(df)
# Out:
# ## Age distribution grouped by gender
